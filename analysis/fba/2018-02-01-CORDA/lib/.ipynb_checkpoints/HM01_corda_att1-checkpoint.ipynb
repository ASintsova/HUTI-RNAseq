# %%
from corda import reaction_confidence
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = "/Users/annasintsova/git_repos/HUTI-RNAseq/analysis/fba/2017-12-16-model-2/data/HM1_homologues/HM1_model/HM1_iJO1366.xml"
genes = "/Users/annasintsova/git_repos/HUTI-RNAseq/analysis/DE/data/processed_counts/2018-01-29_combined_counts.csv"

# %%
hm01_genes=pd.read_csv(genes)
hm01_genes = hm01_genes[["MG1655", "HM01_UR_RPKM", "HM01_UTI_RPKM"]].dropna()
hm01_genes.set_index("MG1655", inplace=True)
hm01_genes.head()
# Out:
# //anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717 DtypeWarning: Columns (6,8,11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#         HM01_UR_RPKM  HM01_UTI_RPKM
# MG1655
# b0689          11.59           2.52
# b3021         110.56           1.64
# b3022         214.17          11.87
# b0341           8.62           3.30
# b1730           5.33           0.81

# %%
def invnorm(x):
    return scipy.stats.norm.ppf((x.rank() -0.5)/x.count())

# %%
hm01=hm01_genes.apply(invnorm)
hm01.head()
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(12, 6))

ax0.hist(hm01.HM01_UR_RPKM,100);

ax1.hist(hm01.HM01_UTI_RPKM,100);

# %%
# Let's start with >2:3 1-2:2, -1:1:1, <-1: -1

def assignConfidence(x):
    if x > 2.0:
        return 3
    elif x >1.0:
        return 2
    elif x > -1.0:
        return 1
    elif x <= -1.0:
        return -1

# %%
hm01["UR_confidence"] = list(map(assignConfidence, hm01.HM01_UR_RPKM.values))
    #UR_confidenceassignConfidence(test.HM01_UR_RPKM.loc[i])
hm01['UTI_confidence'] = list(map(assignConfidence, hm01.HM01_UTI_RPKM))
hm01.head(50)
# Out:
#         HM01_UR_RPKM  HM01_UTI_RPKM  UR_confidence  UTI_confidence
# MG1655
# b0689      -0.938762      -0.398239              1               1
# b3021       0.338562      -0.540551              1               1
# b3022       0.780714       0.204692              1               1
# b0341      -1.058616      -0.310808             -1               1
# b1730      -1.329109      -0.789673             -1               1
# b3618      -0.232849       0.905007              1               1
# b4345      -0.510766       0.074796              1               1
# b4346       0.461953       0.576301              1               1
# b4348      -0.434554       0.383195              1               1
# b4350       0.642508       0.195212              1               1
# b4351       0.251189      -0.177483              1               1
# b0284      -1.403950      -1.005206             -1              -1
# b1337      -1.383498      -1.207159             -1              -1
# b1450      -0.401594      -0.720164              1               1
# b2848      -1.247447      -0.531611             -1               1
# b1335       1.123927       0.742933              2               1
# b2032       0.508121       1.168740              1               2
# b2033       0.771818       1.165679              1               2
# b3817      -1.339482      -1.056584             -1              -1
# b0600       1.063375      -0.484908              2               1
# b0564       0.006969      -1.056584              1              -1
# b2269      -1.451140      -0.697268             -1               1
# b0285      -1.911690      -1.679846             -1              -1
# b0629      -0.311620      -0.301475              1               1
# b0719      -1.202359      -0.942378             -1               1
# b0821       1.074343      -0.534289              2               1
# b0904       1.000086       0.862663              2               1
# b1202      -0.713656      -0.587307              1               1
# b1289      -0.299450       0.168051              1               1
# b1517      -0.656852      -1.635491              1              -1
# b2490      -1.330984      -0.884782             -1               1
# b3121      -2.336552      -0.864913             -1               1
# b3677      -0.574931      -0.429878              1               1
# b3989      -0.742933      -0.352536              1               1
# b4066      -1.603870      -1.384507             -1              -1
# b4120      -0.051131      -0.679115              1               1
# b1514      -1.269672      -2.250688             -1              -1
# b1518      -0.096170      -1.430371              1              -1
# b0350      -1.150537      -1.599681             -1              -1
# b0647      -0.307559      -0.661182              1               1
# b3890      -0.775997      -0.872252              1               1
# b1420      -0.127340      -0.547285              1               1
# b1550       1.892778       0.666975              2               1
# b1557      -0.919683       0.720666              1               1
# b0228       0.012390      -0.683510              1               1
# b0188      -0.164910       0.193239              1               1
# b0559       0.089170      -0.080233              1               1
# b1781      -0.524934      -0.041828              1               1
# b2071      -1.342336      -1.140834             -1              -1
# b3872      -0.935758      -0.517394              1               1

# %%
ur_conf = hm01.UR_confidence.to_dict()

# %%
#Read in the model
from __future__ import print_function
import cobra
base = cobra.io.read_sbml_model(model)

# %%
conf = {}
for r in base.reactions:
    conf[r.id]=reaction_confidence(r.gene_reaction_rule, ur_conf)
conf
# Out:
# {'DM_4CRSOL': 0,
#  'DM_5DRIB': 0,
#  'DM_AACALD': 0,
#  'DM_AMOB': 0,
#  'DM_MTHTHF': 0,
#  'DM_OXAM': 0,
#  'Ec_biomass_iJO1366_WT_53p95M': 0,
#  'Ec_biomass_iJO1366_core_53p95M': 0,
#  'EX_12ppd_DASH_R_LPAREN_e_RPAREN_': 0,
#  'EX_12ppd_DASH_S_LPAREN_e_RPAREN_': 0,
#  'EX_14glucan_LPAREN_e_RPAREN_': 0,
#  'EX_15dap_LPAREN_e_RPAREN_': 0,
#  'EX_23camp_LPAREN_e_RPAREN_': 0,
#  'EX_23ccmp_LPAREN_e_RPAREN_': 0,
#  'EX_23cgmp_LPAREN_e_RPAREN_': 0,
#  'EX_23cump_LPAREN_e_RPAREN_': 0,
#  'EX_23dappa_LPAREN_e_RPAREN_': 0,
#  'EX_26dap_DASH_M_LPAREN_e_RPAREN_': 0,
#  'EX_2ddglcn_LPAREN_e_RPAREN_': 0,
#  'EX_34dhpac_LPAREN_e_RPAREN_': 0,
#  'EX_3amp_LPAREN_e_RPAREN_': 0,
#  'EX_3cmp_LPAREN_e_RPAREN_': 0,
#  'EX_3gmp_LPAREN_e_RPAREN_': 0,
#  'EX_3hcinnm_LPAREN_e_RPAREN_': 0,
#  'EX_3hpp_LPAREN_e_RPAREN_': 0,
#  'EX_3hpppn_LPAREN_e_RPAREN_': 0,
#  'EX_3ump_LPAREN_e_RPAREN_': 0,
#  'EX_4abut_LPAREN_e_RPAREN_': 0,
#  'EX_4hoxpacd_LPAREN_e_RPAREN_': 0,
#  'EX_5dglcn_LPAREN_e_RPAREN_': 0,
#  'EX_5mtr_LPAREN_e_RPAREN_': 0,
#  'EX_LalaDglu_LPAREN_e_RPAREN_': 0,
#  'EX_LalaDgluMdap_LPAREN_e_RPAREN_': 0,
#  'EX_LalaDgluMdapDala_LPAREN_e_RPAREN_': 0,
#  'EX_LalaLglu_LPAREN_e_RPAREN_': 0,
#  'EX_ac_LPAREN_e_RPAREN_': 0,
#  'EX_acac_LPAREN_e_RPAREN_': 0,
#  'EX_acald_LPAREN_e_RPAREN_': 0,
#  'EX_acgal_LPAREN_e_RPAREN_': 0,
#  'EX_acgal1p_LPAREN_e_RPAREN_': 0,
#  'EX_acgam_LPAREN_e_RPAREN_': 0,
#  'EX_acgam1p_LPAREN_e_RPAREN_': 0,
#  'EX_acmana_LPAREN_e_RPAREN_': 0,
#  'EX_acmum_LPAREN_e_RPAREN_': 0,
#  'EX_acnam_LPAREN_e_RPAREN_': 0,
#  'EX_acolipa_LPAREN_e_RPAREN_': 0,
#  'EX_acser_LPAREN_e_RPAREN_': 0,
#  'EX_ade_LPAREN_e_RPAREN_': 0,
#  'EX_adn_LPAREN_e_RPAREN_': 0,
#  'EX_adocbl_LPAREN_e_RPAREN_': 0,
#  'EX_ag_LPAREN_e_RPAREN_': 0,
#  'EX_agm_LPAREN_e_RPAREN_': 0,
#  'EX_akg_LPAREN_e_RPAREN_': 0,
#  'EX_ala_DASH_B_LPAREN_e_RPAREN_': 0,
#  'EX_ala_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_ala_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_alaala_LPAREN_e_RPAREN_': 0,
#  'EX_all_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_alltn_LPAREN_e_RPAREN_': 0,
#  'EX_amp_LPAREN_e_RPAREN_': 0,
#  'EX_anhgm_LPAREN_e_RPAREN_': 0,
#  'EX_arab_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_arbt_LPAREN_e_RPAREN_': 0,
#  'EX_arbtn_LPAREN_e_RPAREN_': 0,
#  'EX_arbtn_DASH_fe3_LPAREN_e_RPAREN_': 0,
#  'EX_arg_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_ascb_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_asn_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_aso3_LPAREN_e_RPAREN_': 0,
#  'EX_asp_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_btn_LPAREN_e_RPAREN_': 0,
#  'EX_but_LPAREN_e_RPAREN_': 0,
#  'EX_butso3_LPAREN_e_RPAREN_': 0,
#  'EX_ca2_LPAREN_e_RPAREN_': 0,
#  'EX_cbi_LPAREN_e_RPAREN_': 0,
#  'EX_cbl1_LPAREN_e_RPAREN_': 0,
#  'EX_cd2_LPAREN_e_RPAREN_': 0,
#  'EX_cgly_LPAREN_e_RPAREN_': 0,
#  'EX_chol_LPAREN_e_RPAREN_': 0,
#  'EX_chtbs_LPAREN_e_RPAREN_': 0,
#  'EX_cit_LPAREN_e_RPAREN_': 0,
#  'EX_cl_LPAREN_e_RPAREN_': 0,
#  'EX_cm_LPAREN_e_RPAREN_': 0,
#  'EX_cmp_LPAREN_e_RPAREN_': 0,
#  'EX_co2_LPAREN_e_RPAREN_': 0,
#  'EX_cobalt2_LPAREN_e_RPAREN_': 0,
#  'EX_colipa_LPAREN_e_RPAREN_': 0,
#  'EX_colipap_LPAREN_e_RPAREN_': 0,
#  'EX_cpgn_LPAREN_e_RPAREN_': 0,
#  'EX_cpgn_DASH_un_LPAREN_e_RPAREN_': 0,
#  'EX_crn_LPAREN_e_RPAREN_': 0,
#  'EX_crn_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_csn_LPAREN_e_RPAREN_': 0,
#  'EX_cu_LPAREN_e_RPAREN_': 0,
#  'EX_cu2_LPAREN_e_RPAREN_': 0,
#  'EX_cyan_LPAREN_e_RPAREN_': 0,
#  'EX_cynt_LPAREN_e_RPAREN_': 0,
#  'EX_cys_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_cys_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_cytd_LPAREN_e_RPAREN_': 0,
#  'EX_dad_DASH_2_LPAREN_e_RPAREN_': 0,
#  'EX_damp_LPAREN_e_RPAREN_': 0,
#  'EX_dca_LPAREN_e_RPAREN_': 0,
#  'EX_dcmp_LPAREN_e_RPAREN_': 0,
#  'EX_dcyt_LPAREN_e_RPAREN_': 0,
#  'EX_ddca_LPAREN_e_RPAREN_': 0,
#  'EX_dgmp_LPAREN_e_RPAREN_': 0,
#  'EX_dgsn_LPAREN_e_RPAREN_': 0,
#  'EX_dha_LPAREN_e_RPAREN_': 0,
#  'EX_dimp_LPAREN_e_RPAREN_': 0,
#  'EX_din_LPAREN_e_RPAREN_': 0,
#  'EX_dms_LPAREN_e_RPAREN_': 0,
#  'EX_dmso_LPAREN_e_RPAREN_': 0,
#  'EX_dopa_LPAREN_e_RPAREN_': 0,
#  'EX_doxrbcn_LPAREN_e_RPAREN_': 0,
#  'EX_dtmp_LPAREN_e_RPAREN_': 0,
#  'EX_dump_LPAREN_e_RPAREN_': 0,
#  'EX_duri_LPAREN_e_RPAREN_': 0,
#  'EX_eca4colipa_LPAREN_e_RPAREN_': 0,
#  'EX_enlipa_LPAREN_e_RPAREN_': 0,
#  'EX_enter_LPAREN_e_RPAREN_': 0,
#  'EX_etha_LPAREN_e_RPAREN_': 0,
#  'EX_ethso3_LPAREN_e_RPAREN_': 0,
#  'EX_etoh_LPAREN_e_RPAREN_': 0,
#  'EX_f6p_LPAREN_e_RPAREN_': 0,
#  'EX_fald_LPAREN_e_RPAREN_': 0,
#  'EX_fe2_LPAREN_e_RPAREN_': 0,
#  'EX_fe3_LPAREN_e_RPAREN_': 0,
#  'EX_fe3dcit_LPAREN_e_RPAREN_': 0,
#  'EX_fe3dhbzs_LPAREN_e_RPAREN_': 0,
#  'EX_fe3hox_LPAREN_e_RPAREN_': 0,
#  'EX_fe3hox_DASH_un_LPAREN_e_RPAREN_': 0,
#  'EX_fecrm_LPAREN_e_RPAREN_': 0,
#  'EX_fecrm_DASH_un_LPAREN_e_RPAREN_': 0,
#  'EX_feenter_LPAREN_e_RPAREN_': 0,
#  'EX_feoxam_LPAREN_e_RPAREN_': 0,
#  'EX_feoxam_DASH_un_LPAREN_e_RPAREN_': 0,
#  'EX_for_LPAREN_e_RPAREN_': 0,
#  'EX_fru_LPAREN_e_RPAREN_': 0,
#  'EX_frulys_LPAREN_e_RPAREN_': 0,
#  'EX_fruur_LPAREN_e_RPAREN_': 0,
#  'EX_fuc_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_fum_LPAREN_e_RPAREN_': 0,
#  'EX_fusa_LPAREN_e_RPAREN_': 0,
#  'EX_g1p_LPAREN_e_RPAREN_': 0,
#  'EX_g3pc_LPAREN_e_RPAREN_': 0,
#  'EX_g3pe_LPAREN_e_RPAREN_': 0,
#  'EX_g3pg_LPAREN_e_RPAREN_': 0,
#  'EX_g3pi_LPAREN_e_RPAREN_': 0,
#  'EX_g3ps_LPAREN_e_RPAREN_': 0,
#  'EX_g6p_LPAREN_e_RPAREN_': 0,
#  'EX_gal_LPAREN_e_RPAREN_': 0,
#  'EX_gal_DASH_bD_LPAREN_e_RPAREN_': 0,
#  'EX_gal1p_LPAREN_e_RPAREN_': 0,
#  'EX_galct_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_galctn_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_galctn_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_galt_LPAREN_e_RPAREN_': 0,
#  'EX_galur_LPAREN_e_RPAREN_': 0,
#  'EX_gam_LPAREN_e_RPAREN_': 0,
#  'EX_gam6p_LPAREN_e_RPAREN_': 0,
#  'EX_gbbtn_LPAREN_e_RPAREN_': 0,
#  'EX_gdp_LPAREN_e_RPAREN_': 0,
#  'EX_glc_LPAREN_e_RPAREN_': 0,
#  'EX_glcn_LPAREN_e_RPAREN_': 0,
#  'EX_glcr_LPAREN_e_RPAREN_': 0,
#  'EX_glcur_LPAREN_e_RPAREN_': 0,
#  'EX_glcur1p_LPAREN_e_RPAREN_': 0,
#  'EX_gln_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_glu_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_gly_LPAREN_e_RPAREN_': 0,
#  'EX_glyald_LPAREN_e_RPAREN_': 0,
#  'EX_glyb_LPAREN_e_RPAREN_': 0,
#  'EX_glyc_LPAREN_e_RPAREN_': 0,
#  'EX_glyc_DASH_R_LPAREN_e_RPAREN_': 0,
#  'EX_glyc2p_LPAREN_e_RPAREN_': 0,
#  'EX_glyc3p_LPAREN_e_RPAREN_': 0,
#  'EX_glyclt_LPAREN_e_RPAREN_': 0,
#  'EX_gmp_LPAREN_e_RPAREN_': 0,
#  'EX_gsn_LPAREN_e_RPAREN_': 0,
#  'EX_gthox_LPAREN_e_RPAREN_': 0,
#  'EX_gthrd_LPAREN_e_RPAREN_': 0,
#  'EX_gtp_LPAREN_e_RPAREN_': 0,
#  'EX_gua_LPAREN_e_RPAREN_': 0,
#  'EX_h_LPAREN_e_RPAREN_': 0,
#  'EX_h2_LPAREN_e_RPAREN_': 0,
#  'EX_h2o_LPAREN_e_RPAREN_': 0,
#  'EX_h2o2_LPAREN_e_RPAREN_': 0,
#  'EX_h2s_LPAREN_e_RPAREN_': 0,
#  'EX_hacolipa_LPAREN_e_RPAREN_': 0,
#  'EX_halipa_LPAREN_e_RPAREN_': 0,
#  'EX_hdca_LPAREN_e_RPAREN_': 0,
#  'EX_hdcea_LPAREN_e_RPAREN_': 0,
#  'EX_hg2_LPAREN_e_RPAREN_': 0,
#  'EX_his_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_hom_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_hxa_LPAREN_e_RPAREN_': 0,
#  'EX_hxan_LPAREN_e_RPAREN_': 0,
#  'EX_idon_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_ile_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_imp_LPAREN_e_RPAREN_': 0,
#  'EX_indole_LPAREN_e_RPAREN_': 0,
#  'EX_inost_LPAREN_e_RPAREN_': 0,
#  'EX_ins_LPAREN_e_RPAREN_': 0,
#  'EX_isetac_LPAREN_e_RPAREN_': 0,
#  'EX_k_LPAREN_e_RPAREN_': 0,
#  'EX_kdo2lipid4_LPAREN_e_RPAREN_': 0,
#  'EX_lac_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_lac_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_lcts_LPAREN_e_RPAREN_': 0,
#  'EX_leu_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_lipa_LPAREN_e_RPAREN_': 0,
#  'EX_lipa_cold_LPAREN_e_RPAREN_': 0,
#  'EX_lipoate_LPAREN_e_RPAREN_': 0,
#  'EX_lys_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_lyx_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_mal_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_mal_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_malt_LPAREN_e_RPAREN_': 0,
#  'EX_malthx_LPAREN_e_RPAREN_': 0,
#  'EX_maltpt_LPAREN_e_RPAREN_': 0,
#  'EX_malttr_LPAREN_e_RPAREN_': 0,
#  'EX_maltttr_LPAREN_e_RPAREN_': 0,
#  'EX_man_LPAREN_e_RPAREN_': 0,
#  'EX_man6p_LPAREN_e_RPAREN_': 0,
#  'EX_manglyc_LPAREN_e_RPAREN_': 0,
#  'EX_melib_LPAREN_e_RPAREN_': 0,
#  'EX_meoh_LPAREN_e_RPAREN_': 0,
#  'EX_met_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_met_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_metsox_DASH_R_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_metsox_DASH_S_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_mg2_LPAREN_e_RPAREN_': 0,
#  'EX_mincyc_LPAREN_e_RPAREN_': 0,
#  'EX_minohp_LPAREN_e_RPAREN_': 0,
#  'EX_mmet_LPAREN_e_RPAREN_': 0,
#  'EX_mn2_LPAREN_e_RPAREN_': 0,
#  'EX_mnl_LPAREN_e_RPAREN_': 0,
#  'EX_mobd_LPAREN_e_RPAREN_': 0,
#  'EX_mso3_LPAREN_e_RPAREN_': 0,
#  'EX_n2o_LPAREN_e_RPAREN_': 0,
#  'EX_na1_LPAREN_e_RPAREN_': 0,
#  'EX_nac_LPAREN_e_RPAREN_': 0,
#  'EX_nh4_LPAREN_e_RPAREN_': 0,
#  'EX_ni2_LPAREN_e_RPAREN_': 0,
#  'EX_nmn_LPAREN_e_RPAREN_': 0,
#  'EX_no_LPAREN_e_RPAREN_': 0,
#  'EX_no2_LPAREN_e_RPAREN_': 0,
#  'EX_no3_LPAREN_e_RPAREN_': 0,
#  'EX_novbcn_LPAREN_e_RPAREN_': 0,
#  'EX_o16a4colipa_LPAREN_e_RPAREN_': 0,
#  'EX_o2_LPAREN_e_RPAREN_': 0,
#  'EX_o2s_LPAREN_e_RPAREN_': 0,
#  'EX_ocdca_LPAREN_e_RPAREN_': 0,
#  'EX_ocdcea_LPAREN_e_RPAREN_': 0,
#  'EX_octa_LPAREN_e_RPAREN_': 0,
#  'EX_orn_LPAREN_e_RPAREN_': 0,
#  'EX_orot_LPAREN_e_RPAREN_': 0,
#  'EX_pacald_LPAREN_e_RPAREN_': 0,
#  'EX_peamn_LPAREN_e_RPAREN_': 0,
#  'EX_phe_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_pheme_LPAREN_e_RPAREN_': 0,
#  'EX_pi_LPAREN_e_RPAREN_': 0,
#  'EX_pnto_DASH_R_LPAREN_e_RPAREN_': 0,
#  'EX_ppa_LPAREN_e_RPAREN_': 0,
#  'EX_ppal_LPAREN_e_RPAREN_': 0,
#  'EX_pppn_LPAREN_e_RPAREN_': 0,
#  'EX_ppt_LPAREN_e_RPAREN_': 0,
#  'EX_pro_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_progly_LPAREN_e_RPAREN_': 0,
#  'EX_psclys_LPAREN_e_RPAREN_': 0,
#  'EX_pser_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_ptrc_LPAREN_e_RPAREN_': 0,
#  'EX_pydam_LPAREN_e_RPAREN_': 0,
#  'EX_pydx_LPAREN_e_RPAREN_': 0,
#  'EX_pydxn_LPAREN_e_RPAREN_': 0,
#  'EX_pyr_LPAREN_e_RPAREN_': 0,
#  'EX_quin_LPAREN_e_RPAREN_': 0,
#  'EX_r5p_LPAREN_e_RPAREN_': 0,
#  'EX_rfamp_LPAREN_e_RPAREN_': 0,
#  'EX_rib_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_rmn_LPAREN_e_RPAREN_': 0,
#  'EX_sbt_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_sel_LPAREN_e_RPAREN_': 0,
#  'EX_ser_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_ser_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_skm_LPAREN_e_RPAREN_': 0,
#  'EX_slnt_LPAREN_e_RPAREN_': 0,
#  'EX_so2_LPAREN_e_RPAREN_': 0,
#  'EX_so3_LPAREN_e_RPAREN_': 0,
#  'EX_so4_LPAREN_e_RPAREN_': 0,
#  'EX_spmd_LPAREN_e_RPAREN_': 0,
#  'EX_succ_LPAREN_e_RPAREN_': 0,
#  'EX_sucr_LPAREN_e_RPAREN_': 0,
#  'EX_sulfac_LPAREN_e_RPAREN_': 0,
#  'EX_tartr_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_tartr_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_taur_LPAREN_e_RPAREN_': 0,
#  'EX_tcynt_LPAREN_e_RPAREN_': 0,
#  'EX_thm_LPAREN_e_RPAREN_': 0,
#  'EX_thr_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_thrp_LPAREN_e_RPAREN_': 0,
#  'EX_thym_LPAREN_e_RPAREN_': 0,
#  'EX_thymd_LPAREN_e_RPAREN_': 0,
#  'EX_tma_LPAREN_e_RPAREN_': 0,
#  'EX_tmao_LPAREN_e_RPAREN_': 0,
#  'EX_tre_LPAREN_e_RPAREN_': 0,
#  'EX_trp_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_tsul_LPAREN_e_RPAREN_': 0,
#  'EX_ttdca_LPAREN_e_RPAREN_': 0,
#  'EX_ttdcea_LPAREN_e_RPAREN_': 0,
#  'EX_ttrcyc_LPAREN_e_RPAREN_': 0,
#  'EX_tungs_LPAREN_e_RPAREN_': 0,
#  'EX_tym_LPAREN_e_RPAREN_': 0,
#  'EX_tyr_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_tyrp_LPAREN_e_RPAREN_': 0,
#  'EX_uacgam_LPAREN_e_RPAREN_': 0,
#  'EX_udpacgal_LPAREN_e_RPAREN_': 0,
#  'EX_udpg_LPAREN_e_RPAREN_': 0,
#  'EX_udpgal_LPAREN_e_RPAREN_': 0,
#  'EX_udpglcur_LPAREN_e_RPAREN_': 0,
#  'EX_ump_LPAREN_e_RPAREN_': 0,
#  'EX_ura_LPAREN_e_RPAREN_': 0,
#  'EX_urea_LPAREN_e_RPAREN_': 0,
#  'EX_uri_LPAREN_e_RPAREN_': 0,
#  'EX_val_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_xan_LPAREN_e_RPAREN_': 0,
#  'EX_xmp_LPAREN_e_RPAREN_': 0,
#  'EX_xtsn_LPAREN_e_RPAREN_': 0,
#  'EX_xyl_DASH_D_LPAREN_e_RPAREN_': 0,
#  'EX_xylu_DASH_L_LPAREN_e_RPAREN_': 0,
#  'EX_zn2_LPAREN_e_RPAREN_': 0,
#  '12DGR120tipp': 0,
#  '12DGR140tipp': 0,
#  '12DGR141tipp': 0,
#  '12DGR160tipp': 0,
#  '12DGR161tipp': 0,
#  '12DGR180tipp': 0,
#  '12DGR181tipp': 0,
#  '12PPDRtex': 3,
#  '12PPDRtpp': 0,
#  '12PPDStex': 3,
#  '12PPDStpp': 0,
#  '14GLUCANabcpp': 1,
#  '14GLUCANtexi': 3,
#  '23CAMPtex': 3,
#  '23CCMPtex': 3,
#  '23CGMPtex': 3,
#  '23CUMPtex': 3,
#  '23DAPPAt2pp': 0,
#  '23DAPPAtex': 3,
#  '23PDE2pp': 1,
#  '23PDE4pp': 1,
#  '23PDE7pp': 1,
#  '23PDE9pp': 1,
#  '26DAHtex': 3,
#  '2AGPA120tipp': 1,
#  '2AGPA140tipp': 1,
#  '2AGPA141tipp': 1,
#  '2AGPA160tipp': 1,
#  '2AGPA161tipp': 1,
#  '2AGPA180tipp': 1,
#  '2AGPA181tipp': 1,
#  '2AGPE120tipp': 1,
#  '2AGPE140tipp': 1,
#  '2AGPE141tipp': 1,
#  '2AGPE160tipp': 1,
#  '2AGPE161tipp': 1,
#  '2AGPE180tipp': 1,
#  '2AGPE181tipp': 1,
#  '2AGPEAT120': 1,
#  '2AGPEAT140': 1,
#  '2AGPEAT141': 1,
#  '2AGPEAT160': 1,
#  '2AGPEAT161': 1,
#  '2AGPEAT180': 1,
#  '2AGPEAT181': 1,
#  '2AGPG120tipp': 1,
#  '2AGPG140tipp': 1,
#  '2AGPG141tipp': 1,
#  '2AGPG160tipp': 1,
#  '2AGPG161tipp': 1,
#  '2AGPG180tipp': 1,
#  '2AGPG181tipp': 1,
#  '2AGPGAT120': 1,
#  '2AGPGAT140': 1,
#  '2AGPGAT141': 1,
#  '2AGPGAT160': 1,
#  '2AGPGAT161': 1,
#  '2AGPGAT180': 1,
#  '2AGPGAT181': 1,
#  '2DGULRGx': 1,
#  '2DGULRGy': 1,
#  '2DGULRx': 1,
#  '2DGULRy': 1,
#  '2MAHMP': 1,
#  '34dhpactex': 3,
#  '3AMACHYD': -1,
#  '3AMPtex': 3,
#  '3CMPtex': 3,
#  '3GMPtex': 3,
#  '3HAD100': 2,
#  '3HAD120': 2,
#  '3HAD121': 2,
#  '3HAD140': 2,
#  '3HAD141': 2,
#  '3HAD160': 2,
#  '3HAD161': 2,
#  '3HAD180': 2,
#  '3HAD181': 2,
#  '3HAD40': 2,
#  '3HAD60': 2,
#  '3HAD80': 2,
#  '3HCINNMH': -1,
#  '3HPPPNH': -1,
#  '3HPPtex': 3,
#  '3HPPtpp': 0,
#  '3KGK': 1,
#  '3NTD2pp': 1,
#  '3NTD4pp': 1,
#  '3NTD7pp': 1,
#  '3NTD9pp': 1,
#  '3OAR100': 0,
#  '3OAR120': 0,
#  '3OAR121': 0,
#  '3OAR140': 0,
#  '3OAR141': 0,
#  '3OAR160': 0,
#  '3OAR161': 0,
#  '3OAR180': 0,
#  '3OAR181': 0,
#  '3OAR40': 0,
#  '3OAR60': 0,
#  '3OAR80': 0,
#  '3OAS100': 2,
#  '3OAS120': 2,
#  '3OAS121': 2,
#  '3OAS140': 2,
#  '3OAS141': 2,
#  '3OAS160': 2,
#  '3OAS161': 2,
#  '3OAS180': 2,
#  '3OAS181': 2,
#  '3OAS60': 2,
#  '3OAS80': 2,
#  '3PEPTabcpp': 1,
#  '3PEPTtex': 3,
#  '3UMPtex': 3,
#  '4HOXPACDtex': 3,
#  '4HTHRS': 1,
#  '4PCP': 1,
#  '4PCPpp': 0,
#  '4PEPTabcpp': 1,
#  '4PEPTtex': 3,
#  '5DGLCNR': 0,
#  '5DGLCNt2rpp': 0,
#  '5DGLCNtex': 3,
#  '5DOAN': 1,
#  '5MTRtex': 3,
#  '5MTRtpp': 0,
#  'A5PISO': 2,
#  'AACPS1': 1,
#  'AACPS2': 1,
#  'AACPS3': 1,
#  'AACPS4': 1,
#  'AACPS5': 1,
#  'AACPS6': 1,
#  'AACPS7': 1,
#  'AACPS8': 1,
#  'AACPS9': 1,
#  'AACTOOR': 0,
#  'AADDGT': 1,
#  'AAMYL': 1,
#  'AAMYLpp': 1,
#  'AB6PGH': 1,
#  'ABTA': 1,
#  'ABUTD': 1,
#  'ABUTt2pp': -1,
#  'ABUTtex': 3,
#  'ACACCT': 3,
#  'ACACT1r': 2,
#  'ACACT2r': 1,
#  'ACACT3r': 1,
#  'ACACT4r': 1,
#  'ACACT5r': 1,
#  'ACACT6r': 1,
#  'ACACT7r': 1,
#  'ACACT8r': 1,
#  'ACACt2pp': 2,
#  'ACACtex': 3,
#  'ACALD': 1,
#  'ACALDtex': 3,
#  'ACALDtpp': 0,
#  'ACANTHAT': 1,
#  'ACBIPGT': 1,
#  'ACCOAC': 1,
#  'ACCOAL': 1,
#  'ACGAL1PPpp': 0,
#  'ACGAL1Ptex': 3,
#  'ACGALtex': 3,
#  'ACGAM1PPpp': 0,
#  'ACGAM1Ptex': 3,
#  'ACGAMK': 1,
#  'ACGAMT': 1,
#  'ACGAptspp': 1,
#  'ACGAtex': 3,
#  'ACGK': 2,
#  'ACGS': 2,
#  'ACHBS': 1,
#  'ACKr': 2,
#  'ACLS': 1,
#  'ACM6PH': 1,
#  'ACMAMUT': 1,
#  'ACMANAptspp': 2,
#  'ACMANAtex': 3,
#  'ACMUMptspp': 1,
#  'ACMUMtex': 3,
#  'ACNAMtex': 3,
#  'ACNML': 1,
#  'ACOAD1f': 1,
#  'ACOAD2f': 1,
#  'ACOAD3f': 1,
#  'ACOAD4f': 1,
#  'ACOAD5f': 1,
#  'ACOAD6f': 1,
#  'ACOAD7f': 1,
#  'ACOAD8f': 1,
#  'ACOATA': 1,
#  'ACODA': 1,
#  'ACOLIPAabctex': 1,
#  'ACONIs': 0,
#  'ACONMT': 1,
#  'ACONTa': 2,
#  'ACONTb': 2,
#  'ACOTA': 1,
#  'ACPPAT120': 1,
#  'ACPPAT140': 1,
#  'ACPPAT141': 1,
#  'ACPPAT160': 1,
#  'ACPPAT161': 1,
#  'ACPPAT180': 1,
#  'ACPPAT181': 1,
#  'ACPS1': 1,
#  'ACS': 1,
#  'ACSERtex': 3,
#  'ACSERtpp': 1,
#  'ACt2rpp': 0,
#  'ACt4pp': 1,
#  'ACtex': 3,
#  'ADA': 1,
#  'ADCL': 1,
#  'ADCS': 1,
#  'ADD': 1,
#  'ADEt2rpp': 0,
#  'ADEtex': 3,
#  'ADK1': 2,
#  'ADK3': 2,
#  'ADK4': 2,
#  'ADMDC': 1,
#  'ADNCYC': 1,
#  'ADNK1': 2,
#  'ADNUC': 1,
#  'ADNt2pp': 1,
#  'ADNtex': 2,
#  'ADOCBIK': 1,
#  'ADOCBLS': 1,
#  'ADOCBLabcpp': 1,
#  'ADOCBLtonex': 1,
#  'ADPRDP': 1,
#  'ADPT': 1,
#  'ADSK': 1,
#  'ADSL1r': 1,
#  'ADSL2r': 1,
#  'ADSS': 2,
#  'AGDC': 1,
#  'AGM3PA': 1,
#  'AGM3PApp': 1,
#  'AGM3PH': 1,
#  'AGM3Pt2pp': 1,
#  'AGM4PA': 1,
#  'AGM4PApp': 1,
#  'AGM4PCP': 1,
#  'AGM4PCPpp': 0,
#  'AGM4PH': 1,
#  'AGM4Pt2pp': 1,
#  'AGMH': 1,
#  'AGMHE': 2,
#  'AGMT': 0,
#  'AGMt2pp': 1,
#  'AGMtex': 3,
#  'AGPAT120': 1,
#  'AGPAT140': 1,
#  'AGPAT141': 1,
#  'AGPAT160': 1,
#  'AGPAT161': 1,
#  'AGPAT180': 1,
#  'AGPAT181': 1,
#  'AGPR': 2,
#  'AGt3': -1,
#  'AHCYSNS': 1,
#  'AICART': 1,
#  'AIRC2': 1,
#  'AIRC3': 1,
#  'AKGDH': 2,
#  'AKGt2rpp': 1,
#  'AKGtex': 3,
#  'ALAALAD': -1,
#  'ALAALAabcpp': 1,
#  'ALAALAr': 1,
#  'ALAALAtex': 3,
#  'ALAGLUE': 1,
#  'ALAR': 1,
#  'ALATA_D2': 2,
#  'ALATA_L': 2,
#  'ALATA_L2': 2,
#  'ALATRS': 2,
#  'ALAabcpp': 0,
#  'ALAt2pp': 1,
#  'ALAt2rpp': 0,
#  'ALAt4pp': 1,
#  'ALAtex': 3,
#  'ALCD19': 1,
#  'ALCD2x': 1,
#  'ALDD2x': -1,
#  'ALDD2y': 1,
#  'ALDD3y': 1,
#  'ALDD4': 0,
#  'ALLTAMH': 1,
#  'ALLTN': -1,
#  'ALLTNt2rpp': -1,
#  'ALLTNtex': 3,
#  'ALLtex': 3,
#  'ALPATE160pp': 1,
#  'ALPATG160pp': 1,
#  'ALR2': 1,
#  'ALR4x': 1,
#  'ALTRH': 2,
#  'AM3PA': 1,
#  'AM4PA': 1,
#  'AM4PCP': 1,
#  'AMALT1': 1,
#  'AMALT2': 1,
#  'AMALT3': 1,
#  'AMALT4': 1,
#  'AMANAPEr': 1,
#  'AMANK': 1,
#  'AMAOTr': -1,
#  'AMMQLT8': 1,
#  'AMPMS2': -1,
#  'AMPN': 2,
#  'AMPTASECG': 2,
#  'AMPTASEPG': 2,
#  'AMPtex': 3,
#  'ANHGMtex': 3,
#  'ANHMK': 1,
#  'ANPRT': -1,
#  'ANS': -1,
#  'AOBUTDs': 0,
#  'AOXSr2': 0,
#  'AP4AH': 1,
#  'AP4AS': 0,
#  'AP5AH': 1,
#  'APCS': 1,
#  'APG3PAT120': 1,
#  'APG3PAT140': 1,
#  'APG3PAT141': 1,
#  'APG3PAT160': 1,
#  'APG3PAT161': 1,
#  'APG3PAT180': 1,
#  'APG3PAT181': 1,
#  'APH120': 1,
#  'APH140': 1,
#  'APH141': 1,
#  'APH160': 1,
#  'APH161': 1,
#  'APH180': 1,
#  'APH181': 1,
#  'APPLDHr': 1,
#  'APRAUR': 1,
#  'ARAI': 1,
#  'ARBTNR1': 0,
#  'ARBTNR2': 0,
#  'ARBTNR3': 0,
#  'ARBTNabcpp': 0,
#  'ARBTNexs': 0,
#  'ARBTNtex': 0,
#  'ARBTNtonex': 0,
#  'ARBTNtpp': 0,
#  'ARBTptspp': 0,
#  'ARBTtex': 3,
#  'ARBabcpp': 1,
#  'ARBt2rpp': 0,
#  'ARBt3ipp': 1,
#  'ARBtex': 3,
#  'ARGAGMt7pp': -1,
#  'ARGDC': -1,
#  'ARGDCpp': 1,
#  'ARGORNt7pp': 0,
#  'ARGSL': 2,
#  'ARGSS': 2,
#  'ARGTRS': 1,
#  'ARGabcpp': 1,
#  'ARGt3pp': 1,
#  'ARGtex': 3,
#  'ASAD': 2,
#  'ASCBPL': 1,
#  'ASCBptspp': -1,
#  'ASCBtex': 3,
#  'ASNN': 1,
#  'ASNNpp': 1,
#  'ASNS1': 1,
#  'ASNS2': 1,
#  'ASNTRS': 1,
#  'ASNabcpp': 0,
#  'ASNt2rpp': -1,
#  'ASNtex': 3,
#  'ASO3t8pp': 0,
#  'ASO3tex': 3,
#  'ASP1DC': 2,
#  'ASPCT': 1,
#  'ASPK': 2,
#  'ASPO3': 1,
#  'ASPO4': 1,
#  'ASPO5': 1,
#  'ASPO6': 1,
#  'ASPT': 1,
#  'ASPTA': 2,
#  'ASPTRS': 1,
#  'ASPabcpp': 1,
#  'ASPt2_2pp': 0,
#  'ASPt2_3pp': 1,
#  'ASPt2pp': 0,
#  'ASPt2rpp': 0,
#  'ASPtex': 3,
#  'ASR': 1,
#  'AST': -1,
#  'ATHRDHr': 1,
#  'ATPHs': 0,
#  'ATPM': 0,
#  'ATPPRT': 1,
#  'BALAt2pp': 1,
#  'BALAtex': 3,
#  'BETALDHx': 1,
#  'BETALDHy': 1,
#  'BMOCOS': 1,
#  'BMOGDS1': 1,
#  'BMOGDS2': 1,
#  'BPNT': 1,
#  'BSORx': 0,
#  'BSORy': 0,
#  'BTNt2ipp': 0,
#  'BTNtex': 3,
#  'BTS5': -1,
#  'BUTCT': 3,
#  'BUTSO3abcpp': -1,
#  'BUTSO3tex': 3,
#  'BUTt2rpp': 2,
#  'BUTtex': 3,
#  'BWCOGDS1': 1,
#  'BWCOGDS2': 1,
#  'BWCOS': 1,
#  'CA2t3pp': 1,
#  'CA2tex': 3,
#  'CADVtpp': -1,
#  'CAT': 2,
#  'CAt6pp': 1,
#  'CBIAT': 1,
#  'CBItonex': 1,
#  'CBIuabcpp': 1,
#  'CBL1abcpp': 1,
#  'CBL1tonex': 1,
#  'CBLAT': 1,
#  'CBMD': 0,
#  'CBMKr': 1,
#  'CBPS': 1,
#  'CCGS': 1,
#  'CD2abcpp': 1,
#  'CD2t3pp': 1,
#  'CD2tex': 3,
#  'CD2tpp': 1,
#  'CDAPPA120': 1,
#  'CDAPPA140': 1,
#  'CDAPPA141': 1,
#  'CDAPPA160': 1,
#  'CDAPPA161': 1,
#  'CDAPPA180': 1,
#  'CDAPPA181': 1,
#  'CDGR': 1,
#  'CDGS': 0,
#  'CDPMEK': 0,
#  'CFAS160E': 2,
#  'CFAS160G': 2,
#  'CFAS180E': 2,
#  'CFAS180G': 2,
#  'CGLYabcpp': 1,
#  'CGLYtex': 3,
#  'CHLabcpp': -1,
#  'CHLt2pp': 1,
#  'CHLtex': 3,
#  'CHOLD': 1,
#  'CHORM': 1,
#  'CHORS': 1,
#  'CHRPL': 1,
#  'CHTBSptspp': 2,
#  'CHTBStex': 3,
#  'CINNDO': -1,
#  'CITL': 1,
#  'CITt3pp': 0,
#  'CITt7pp': 1,
#  'CITtex': 3,
#  'CLIPAabctex': 1,
#  'CLPNH120pp': 0,
#  'CLPNH140pp': 0,
#  'CLPNH141pp': 0,
#  'CLPNH160pp': 0,
#  'CLPNH161pp': 0,
#  'CLPNH180pp': 0,
#  'CLPNH181pp': 0,
#  'CLPNS120pp': 0,
#  'CLPNS140pp': 0,
#  'CLPNS141pp': 0,
#  'CLPNS160pp': 0,
#  'CLPNS161pp': 0,
#  'CLPNS180pp': 0,
#  'CLPNS181pp': 0,
#  'CLt3_2pp': 1,
#  'CLtex': 3,
#  'CMPN': 0,
#  'CMPtex': 3,
#  'CMtex': 3,
#  'CMtpp': 0,
#  'CO2tex': 3,
#  'CO2tpp': 0,
#  'COBALT2abcpp': 1,
#  'COBALT2t3pp': 1,
#  'COBALT2tex': 3,
#  'COBALT2tpp': 1,
#  'COLIPAKpp': 1,
#  'COLIPAPabctex': 1,
#  'COLIPAabcpp': 1,
#  'COLIPAabctex': 1,
#  'CPGNR1': 0,
#  'CPGNR2': 0,
#  'CPGNR3': 0,
#  'CPGNUtex': 0,
#  'CPGNUtpp': 0,
#  'CPGNabcpp': 0,
#  'CPGNexs': 0,
#  'CPGNtonex': 1,
#  'CPH4S': 1,
#  'CPMPS': 1,
#  'CPPPGO': 1,
#  'CPPPGO2': 1,
#  'CRNBTCT': 1,
#  'CRNCAL2': 1,
#  'CRNCAR': 0,
#  'CRNCBCT': 1,
#  'CRNCDH': 0,
#  'CRNDCAL2': 1,
#  'CRNDabcpp': -1,
#  'CRNDt2rpp': 1,
#  'CRNDtex': 3,
#  'CRNabcpp': -1,
#  'CRNt2rpp': 1,
#  'CRNt7pp': 0,
#  'CRNt8pp': 0,
#  'CRNtex': 3,
#  'CS': 2,
#  'CSND': 1,
#  'CSNt2pp': -1,
#  'CSNtex': 3,
#  'CTBTCAL2': 1,
#  'CTBTabcpp': -1,
#  'CTBTt2rpp': 1,
#  'CTECOAI6': 1,
#  'CTECOAI7': 1,
#  'CTECOAI8': 1,
#  'CTPS2': 2,
#  'CU1Opp': 1,
#  'CU1abcpp': 1,
#  'CU2abcpp': 1,
#  'CU2tex': 3,
#  'CU2tpp': 1,
#  'CUt3': -1,
#  'CUtex': 3,
#  'CYANST': 1,
#  'CYANSTpp': 1,
#  'CYANtex': 3,
#  'CYNTAH': 1,
#  'CYNTt2pp': -1,
#  'CYNTtex': 3,
#  'CYSDDS': 1,
#  'CYSDS': 3,
#  'CYSDabcpp': 0,
#  'CYSDtex': 3,
#  'CYSS': 2,
#  'CYSSADS': 1,
#  'CYSTL': 1,
#  'CYSTRS': 1,
#  'CYSabc2pp': 1,
#  'CYSabcpp': 0,
#  'CYStex': 3,
#  'CYStpp': 1,
#  'CYTBD2pp': 0,
#  'CYTBDpp': 0,
#  'CYTBO3_4pp': 1,
#  'CYTD': 1,
#  'CYTDH': 1,
#  'CYTDK2': 1,
#  'CYTDt2pp': 1,
#  'CYTDtex': 3,
#  'CYTK1': 2,
#  'CYTK2': 2,
#  'D_DASH_LACt2pp': 0,
#  'D_DASH_LACtex': 3,
#  'DAAD': 1,
#  'DADA': 1,
#  'DADK': 2,
#  'DADNt2pp': 1,
#  'DADNtex': 2,
#  'DAGK120': 1,
#  'DAGK140': 1,
#  'DAGK141': 1,
#  'DAGK160': 1,
#  'DAGK161': 1,
#  'DAGK180': 1,
#  'DAGK181': 1,
#  'DALAt2pp': 1,
#  'DALAtex': 3,
#  'DAMPtex': 3,
#  'DAPAL': -1,
#  'DAPDC': 1,
#  'DAPE': 1,
#  'DAPabcpp': 0,
#  'DAPtex': 3,
#  'DASYN120': 1,
#  'DASYN140': 1,
#  'DASYN141': 1,
#  'DASYN160': 1,
#  'DASYN161': 1,
#  'DASYN180': 1,
#  'DASYN181': 1,
#  'DATPHs': 0,
#  'DB4PS': 1,
#  'DBTS': -1,
#  'DC6PH': 1,
#  'DCAtex': 3,
#  'DCMPtex': 3,
#  'DCTPD': 1,
#  'DCYTD': 1,
#  'DCYTt2pp': 1,
#  'DCYTtex': 2,
#  'DDCAtexi': 1,
#  'DDGALK': 2,
#  'DDGLCNt2rpp': 1,
#  'DDGLCNtex': 3,
#  'DDGLK': 2,
#  'DDPA': 2,
#  'DDPGALA': 0,
#  'DGK1': 2,
#  'DGMPtex': 3,
#  'DGSNt2pp': 1,
#  'DGSNtex': 3,
#  'DHAD1': 1,
#  'DHAD2': 1,
#  'DHAPT': 0,
#  'DHAtex': 3,
#  'DHAtpp': 0,
#  'DHBD': 1,
#  'DHBS': 0,
#  'DHBSH': 0,
#  'DHCIND': -1,
#  'DHCINDO': -1,
#  'DHDPRy': 1,
#  'DHDPS': 2,
#  'DHFR': 1,
#  'DHFS': 1,
#  'DHMPTR': 1,
#  'DHNAOT4': 1,
#  'DHNCOAS': 1,
#  'DHNCOAT': 1,
#  'DHNPA2r': 1,
#  'DHNPTE': 1,
#  'DHORD2': 1,
#  'DHORD5': 1,
#  'DHORDfum': 0,
#  'DHORTS': 1,
#  'DHPPD': -1,
#  'DHPPDA2': 1,
#  'DHPS2': 1,
#  'DHPTDCs2': 0,
#  'DHPTDNR': 1,
#  'DHPTDNRN': 1,
#  'DHPTPE': 2,
#  'DHQS': 1,
#  'DHQTi': 1,
#  'DIMPtex': 3,
#  'DINSt2pp': 1,
#  'DINStex': 3,
#  'DKGLCNR1': 1,
#  ...}

# %%
from corda import CORDA
opt = CORDA(base, conf,)
x = opt.build()
print(x)
# Out:
# None

# %%
opt.support
# Out:
# 5

# %%
print([opt.model.reactions.get_by_id(k).reaction for k, used in opt.included.items() if used])
# Out:
# ['5mtr_e --> ', 'ac_e --> ', 'asp_DASH_L_e --> ', 'cit_e --> ', 'co2_e <=> ', 'dha_e --> ', 'for_e --> ', 'glc_DASH_D_e <=> ', 'glu_DASH_L_e --> ', 'gly_e --> ', 'h_e <=> ', 'h2o_e <=> ', 'h2s_e --> ', 'mal_DASH_L_e --> ', 'nh4_e <=> ', 'o2_e <=> ', 'so4_e <=> ', 'spmd_e --> ', '12ppd_DASH_R_e <=> 12ppd_DASH_R_p', '12ppd_DASH_S_e <=> 12ppd_DASH_S_p', '23camp_e <=> 23camp_p', '23ccmp_e <=> 23ccmp_p', '23cgmp_e <=> 23cgmp_p', '23cump_e <=> 23cump_p', '23dappa_e <=> 23dappa_p', '26dap_DASH_M_e <=> 26dap_DASH_M_p', '34dhpac_e <=> 34dhpac_p', '3amp_e <=> 3amp_p', '3cmp_e <=> 3cmp_p', '3gmp_e <=> 3gmp_p', '3hpp_e <=> 3hpp_p', 'LalaDgluMdap_e <=> LalaDgluMdap_p', '3ump_e <=> 3ump_p', '4hoxpacd_e <=> 4hoxpacd_p', 'LalaDgluMdapDala_e <=> LalaDgluMdapDala_p', '5dglcn_e <=> 5dglcn_p', '5mtr_e <=> 5mtr_p', '5mtr_c + h_c --> 5mtr_p + h_p', '4abut_e <=> 4abut_p', 'acac_e <=> acac_p', 'acald_e <=> acald_p', 'acgal1p_e <=> acgal1p_p', 'acgal_e <=> acgal_p', 'acgam1p_e <=> acgam1p_p', 'acgam_e <=> acgam_p', 'acglu_c + atp_c --> acg5p_c + adp_c', 'accoa_c + glu_DASH_L_c --> acglu_c + coa_c + h_c', 'ac_c + atp_c <=> actp_c + adp_c', 'acmana_e <=> acmana_p', 'acnam_e <=> acnam_p', 'acorn_c + h2o_c --> ac_c + orn_c', 'cit_c <=> acon_DASH_C_c + h2o_c', 'acon_DASH_C_c + h2o_c <=> icit_c', 'acorn_c + akg_c <=> acg5sa_c + glu_DASH_L_c', 'acser_e <=> acser_p', 'ac_p + h_p <=> ac_c + h_c', 'ac_e <=> ac_p', 'ade_e <=> ade_p', 'amp_c + atp_c <=> 2.0 adp_c', 'amet_c + h_c --> ametam_c + co2_c', 'adn_c + atp_c --> adp_c + amp_c + h_c', 'ade_c + prpp_c --> amp_c + ppi_c', 'aps_c + atp_c --> adp_c + h_c + paps_c', 'agm_e <=> agm_p', 'acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + nadph_c', 'akg_e <=> akg_p', 'alaala_e <=> alaala_p', 'ala_DASH_L_e <=> ala_DASH_L_p', 'alltn_e <=> alltn_p', 'all_DASH_D_e <=> all_DASH_D_p', 'amp_e <=> amp_p', 'anhgm_e <=> anhgm_p', 'arab_DASH_L_e <=> arab_DASH_L_p', 'arg_DASH_L_e <=> arg_DASH_L_p', 'aspsa_c + nadp_c + pi_c <=> 4pasp_c + h_c + nadph_c', 'ascb_DASH_L_e <=> ascb_DASH_L_p', 'asn_DASH_L_e <=> asn_DASH_L_p', 'aso3_e <=> aso3_p', 'asp_DASH_L_c + atp_c <=> 4pasp_c + adp_c', 'akg_c + asp_DASH_L_c <=> glu_DASH_L_c + oaa_c', 'asp_DASH_L_p + h_p <=> asp_DASH_L_c + h_c', 'asp_DASH_L_e <=> asp_DASH_L_p', 'atp_c + h2o_c --> adp_c + h_c + pi_c', 'ala_DASH_B_e <=> ala_DASH_B_p', 'h2o_c + pap_c --> amp_c + pi_c', 'btn_e <=> btn_p', 'butso3_e <=> butso3_p', 'but_e <=> but_p', 'ca2_e <=> ca2_p', 'cd2_e <=> cd2_p', 'cgly_e <=> cgly_p', 'chol_e <=> chol_p', 'chtbs_e <=> chtbs_p', 'cit_c + h_p --> cit_p + h_c', 'cit_e <=> cit_p', 'cl_e <=> cl_p', 'cmp_e <=> cmp_p', 'cm_e <=> cm_p', 'co2_e <=> co2_p', 'co2_p <=> co2_c', 'cobalt2_e <=> cobalt2_p', 'crn_DASH_D_e <=> crn_DASH_D_p', 'crn_e <=> crn_p', 'accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c', 'csn_e <=> csn_p', 'cu2_e <=> cu2_p', 'cu_e <=> cu_p', 'cyan_e <=> cyan_p', 'cynt_e <=> cynt_p', 'cys_DASH_L_c + h2o_c --> h2s_c + nh4_c + pyr_c', 'cys_DASH_D_e <=> cys_DASH_D_p', 'acser_c + h2s_c --> ac_c + cys_DASH_L_c + h_c', 'cyst_DASH_L_c + h2o_c --> hcys_DASH_L_c + nh4_c + pyr_c', 'cys_DASH_L_e <=> cys_DASH_L_p', '2.0 h_c + mql8_c + 0.5 o2_c --> h2o_c + 2.0 h_p + mqn8_c', '2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_p + q8_c', 'cytd_e <=> cytd_p', 'lac_DASH_D_e <=> lac_DASH_D_p', 'ala_DASH_D_e <=> ala_DASH_D_p', 'damp_e <=> damp_p', '15dap_e <=> 15dap_p', 'dca_e <=> dca_p', 'dcmp_e <=> dcmp_p', '2ddglcn_e <=> 2ddglcn_p', 'dgmp_e <=> dgmp_p', 'dgsn_e <=> dgsn_p', 'dha_c + pep_c --> dhap_c + pyr_c', 'dha_e <=> dha_p', 'dha_p <=> dha_c', 'dimp_e <=> dimp_p', 'din_e <=> din_p', 'dmso_e <=> dmso_p', 'dms_e <=> dms_p', 'dopa_e <=> dopa_p', 'doxrbcn_e <=> doxrbcn_p', 'ser_DASH_D_e <=> ser_DASH_D_p', 'dtmp_e <=> dtmp_p', 'dump_e <=> dump_p', '2pg_c <=> h2o_c + pep_c', 'etha_e <=> etha_p', 'ethso3_e <=> ethso3_p', 'etoh_e <=> etoh_p', 'f6p_c <=> dha_c + g3p_c', 'f6p_e <=> f6p_p', 'h2o_c + hxcoa_c --> coa_c + h_c + hxa_c', 'fald_e <=> fald_p', 'fe2_e <=> fe2_p', 'fe3_e <=> fe3_p', 'for_e <=> for_p ...

# %%
base.problem.Objective(base.objective.expression)

# %%
base.objective = "Ec_biomass_iJO1366_core_53p95M"

# %%
biomass_rx = base.reactions.get_by_id("Ec_biomass_iJO1366_core_53p95M")

# %%
base.objective

# %%
from cobra.util.solver import linear_reaction_coefficients
linear_reaction_coefficients(base)
# Out:
# {<Reaction Ec_biomass_iJO1366_core_53p95M at 0x11cd453c8>: 1.0}

# %%
base
# Out:
# <Model HM1_iJO1366 at 0x118e1fe80>

# %%
opt.model
# Out:
# <Model HM1_iJO1366 at 0x11bcbee80>

# %%
opt.model.objective=base.objective = "Ec_biomass_iJO1366_core_53p95M"

# %%
opt.model
# Out:
# <Model HM1_iJO1366 at 0x11bcbee80>

# %%
opt.model.optimize().objective_value
# Out:
# 0.0
