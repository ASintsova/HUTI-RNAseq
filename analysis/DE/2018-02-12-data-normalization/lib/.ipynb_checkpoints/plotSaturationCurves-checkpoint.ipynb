# %% [markdown]
# # Saturation Curves
#
# * In this example plotting % of sequence file subsampled vs # of genes that had 10 or more reads
# * other info I want is the total number of reads alinged to bacterial genome for each sample

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

data = "/Users/annasintsova/git_repos/HUTI-RNAseq/analysis/DE/2018-02-12-data-normalization/data/2018-02-18-saturation_data-HM01HM03.csv"
total_reads_data = "/Users/annasintsova/git_repos/HUTI-RNAseq/data/counts/flagstat/flagstat_summary.txt"

# %%
sc_df = pd.read_csv(data, index_col = 0)
sc_df.index = [float(i.split("%")[0]) for i in list(sc_df.index)]
sc_df
# Out:
#        HM01_UR  HM01_UTI  HM03_UR  HM03_UTI
# 0.1      339.8      71.4    425.0     139.4
# 0.5     1497.2     304.4   1821.6     590.2
# 1.0     2334.8     574.0   2586.6    1016.6
# 10.0    4530.4    2311.6   4268.8    2727.0
# 50.0    5184.6    3709.8   4642.6    3903.2
# 75.0    5261.2    4064.4   4679.8    4125.0
# 100.0   5293.0    4270.0   4698.0    4269.0

# %%
def plotSampleSatCurve(strains):#ex. ["HM01", "HM03"]
    for strain in strains:
        cols_to_plot = [c for c in list(sc_df.columns) if strain in c]
        print(cols_to_plot)
        plt.figure()
        plt.plot(sc_df[cols_to_plot[0]], '-ob', sc_df[cols_to_plot[1]], '-or')
        plt.ylabel("# of genes with 10 or more reads")
        plt.xlabel ("% of reads subsampled")
        plt.legend(cols_to_plot)
        ax = plt.gca()
        ax.set_facecolor("0.97")

# %%
plotSampleSatCurve(['HM01', 'HM03'])
# Out:
# ['HM01_UR', 'HM01_UTI']
# ['HM03_UR', 'HM03_UTI']

# %% [markdown]
# * Now want to see if there's a relationship between how many reads aligned, and level at which samples plateau

# %%
flagstat_df = pd.read_csv(total_reads_data, index_col=0)
flagstat_df.index = [i.split("_trimmed_")[0] for i in list(flagstat_df.index)]
flagstat_df['genes_covered'] = sc_df.T[100.0]
test = flagstat_df[0:4]
# Out:
#          genome sample attr  total_reads    mapped  genes_covered
# HM01_UR    HM01     UR  NaN     17288419  16480326         5293.0
# HM01_UTI   HM01    UTI  NaN     18496607   3717040         4270.0
# HM03_UR    HM03     UR  NaN     21354719  20927541         4698.0
# HM03_UTI   HM03    UTI  NaN     16544044   8059076         4269.0

# %%
# Out:
# ['blue', 'red', 'blue', 'red']

# %%
colors = ['blue' if "UR" in c else 'red' for c in list(test.index)]
genes = test.genes_covered
reads_mapped =  test.mapped
plt.scatter(genes, reads_mapped, color=colors)

for label, genes, reads_mapped in zip(list(test.index), test.genes_covered, test.mapped):
    plt.annotate(label,
    xy=(genes, reads_mapped), 
    xytext=(5, -5), # but slightly offset
    textcoords='offset points')

# %%
def plotSampleSatCurveMillionReads(strains):   
    for strain in strains:
        cols_to_plot = [c for c in list(sc_df.columns) if strain in c]
        print(cols_to_plot)
        reads_mapped = [ flagstat_df.mapped[c] for c in cols_to_plot]
        x1 = list(reads_mapped[0]*(sc_df.index)/100)
        x2 = list(reads_mapped[1]*(sc_df.index)/100)
        y1 = sc_df[cols_to_plot[0]]
        y2 = sc_df[cols_to_plot[1]]
        plt.figure()
        plt.plot(x1, y1, '-ob', x2, y2 , '-or')
        plt.ylabel("# of genes with 10 or more reads")
        plt.xlabel ("# of reads subsampled")
        plt.legend(cols_to_plot)
        ax = plt.gca()
        ax.set_facecolor("0.97")

# %%
plotSampleSatCurveMillionReads(["HM01", "HM03"])
# Out:
# ['HM01_UR', 'HM01_UTI']
# ['HM03_UR', 'HM03_UTI']

# %%
flagstat_df.mapped['HM01_UR']
# Out:
# 16480326

# %%
sc_df.index/100*16480326
# Out:
# Float64Index([16480.326, 82401.63, 164803.26, 1648032.6, 8240163.0, 12360244.5,
#               16480326.0],
#              dtype='float64')
