# %% [markdown]
# # Merging the count data

# %%
import pandas as pd

# %%
strain_nums = [1, 3, 6, 7, 14, 17, 43, 54, 56, 57, 66, 68, 86 ]
media = ['UR', 'UTI']
filenames = []
for strain in strain_nums:
    for m in media:
        s = m + str(strain)
        filenames.append(s)
filenames.remove("UR1")

# %%
comb = pd.read_table("UR1", sep = "\t", header = None)
comb.columns = ["Gene_id", 'UR1']
comb = comb.set_index("Gene_id")

# %%
for name in filenames:
    x = pd.read_table(name, sep = "\t", header = None)
    x.columns = ["Gene_id", name]
    x = x.set_index("Gene_id")
    comb = pd.merge(comb, x, how='outer', left_index=True, right_index=True)
print (comb.head())
# Out:
#                                           UR1  UTI1  UR3  UTI3     UR6  UTI6  \
# Gene_id
# 10001_aldA_1                              NaN   NaN  NaN   NaN   245.0   9.0
# 10002_aldA_2                              NaN   NaN  NaN   NaN   209.0   5.0
# 10011_ydbC_2                              NaN   NaN  NaN   NaN   110.0   4.0
# 10012_putative_autotransporter_precursor  NaN   NaN  NaN   NaN  1364.0  41.0
# 10013_hypothetical_protein                NaN   NaN  NaN   NaN     NaN   NaN
#
#                                             UR7  UTI7  UR14  UTI14  ...    \
# Gene_id                                                             ...
# 10001_aldA_1                                NaN   NaN   NaN    NaN  ...
# 10002_aldA_2                                NaN   NaN   NaN    NaN  ...
# 10011_ydbC_2                              140.0   2.0   NaN    NaN  ...
# 10012_putative_autotransporter_precursor    NaN   NaN   NaN    NaN  ...
# ...

# %%
comb.tail(10)
# Out:
#                                       UR1        UTI1        UR3       UTI3  \
# Gene_id
# 9986_ydcO_1                           NaN         NaN        NaN        NaN
# 9987_ydcO_2                           NaN         NaN        NaN        NaN
# 9997_trg                              NaN         NaN        NaN        NaN
# 99_hypothetical_protein               0.0         0.0        NaN        NaN
# 9_Phage_major_capsid_protein_E        0.0         0.0        NaN        NaN
# __alignment_not_unique                0.0         0.0        0.0        0.0
# __ambiguous                      422408.0    146804.0   314434.0   171333.0
# __no_feature                    3522200.0    533691.0  3816096.0  1204805.0
# __not_aligned                    764480.0  14775419.0   414293.0  8481744.0
# __too_low_aQual                  807094.0    112746.0   522423.0   221155.0
#
#                                       UR6        UTI6        UR7        UTI7  \
# Gene_id
# ...

# %%
df = comb.copy()

# %%
df.tail(10)
# Out:
#                                       UR1        UTI1        UR3       UTI3  \
# Gene_id
# 9986_ydcO_1                           NaN         NaN        NaN        NaN
# 9987_ydcO_2                           NaN         NaN        NaN        NaN
# 9997_trg                              NaN         NaN        NaN        NaN
# 99_hypothetical_protein               0.0         0.0        NaN        NaN
# 9_Phage_major_capsid_protein_E        0.0         0.0        NaN        NaN
# __alignment_not_unique                0.0         0.0        0.0        0.0
# __ambiguous                      422408.0    146804.0   314434.0   171333.0
# __no_feature                    3522200.0    533691.0  3816096.0  1204805.0
# __not_aligned                    764480.0  14775419.0   414293.0  8481744.0
# __too_low_aQual                  807094.0    112746.0   522423.0   221155.0
#
#                                       UR6        UTI6        UR7        UTI7  \
# Gene_id
# ...

# %%
comb = comb.drop(["__alignment_not_unique", "__ambiguous", "__no_feature", "__not_aligned", "__too_low_aQual"])

# %%
comb.tail()
# Out:
#                                 UR1  UTI1  UR3  UTI3   UR6  UTI6  UR7  UTI7  \
# Gene_id
# 9986_ydcO_1                     NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 9987_ydcO_2                     NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 9997_trg                        NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 99_hypothetical_protein         0.0   0.0  NaN   NaN  57.0   0.0  NaN   NaN
# 9_Phage_major_capsid_protein_E  0.0   0.0  NaN   NaN   NaN   NaN  NaN   NaN
#
#                                 UR14  UTI14  ...    UR56  UTI56   UR57  UTI57  \
# Gene_id                                      ...
# 9986_ydcO_1                      NaN    NaN  ...     NaN    NaN    NaN    NaN
# 9987_ydcO_2                      NaN    NaN  ...     NaN    NaN    NaN    NaN
# 9997_trg                         NaN    NaN  ...     NaN    NaN  191.0    5.0
# 99_hypothetical_protein          NaN    NaN  ...    35.0    2.0    NaN    NaN
# ...

# %%
comb.to_csv("combined_counts.csv")

# %%
df = pd.read_csv("combined_counts.csv")

# %%
df.head()
# Out:
#                                     Gene_id  UR1  UTI1  UR3  UTI3     UR6  \
# 0                              10001_aldA_1  NaN   NaN  NaN   NaN   245.0
# 1                              10002_aldA_2  NaN   NaN  NaN   NaN   209.0
# 2                              10011_ydbC_2  NaN   NaN  NaN   NaN   110.0
# 3  10012_putative_autotransporter_precursor  NaN   NaN  NaN   NaN  1364.0
# 4                10013_hypothetical_protein  NaN   NaN  NaN   NaN     NaN
#
#    UTI6    UR7  UTI7  UR14  ...      UR56   UTI56    UR57  UTI57  UR66  UTI66  \
# 0   9.0    NaN   NaN   NaN  ...       NaN     NaN     NaN    NaN   NaN    NaN
# 1   5.0    NaN   NaN   NaN  ...       NaN     NaN     NaN    NaN   NaN    NaN
# 2   4.0  140.0   2.0   NaN  ...       NaN     NaN     NaN    NaN   0.0    0.0
# 3  41.0    NaN   NaN   NaN  ...    3953.0  1134.0  1887.0   11.0  13.0    0.0
# 4   NaN    NaN   NaN   NaN  ...       NaN     NaN     NaN    NaN   NaN    NaN
#
#      UR68  UTI68    UR86  UTI86
# ...
